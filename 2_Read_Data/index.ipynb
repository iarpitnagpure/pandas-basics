# %%
import pandas as pd

# Read data from csv file
newData = pd.read_csv('../obesity_prediction.csv')
newData
# Out:
#       Gender        Age    Height      Weight family_history FAVC  FCVC  NCP  \
# 0     Female  21.000000  1.620000   64.000000            yes   no   2.0  3.0
# 1     Female  21.000000  1.520000   56.000000            yes   no   3.0  3.0
# 2       Male  23.000000  1.800000   77.000000            yes   no   2.0  3.0
# 3       Male  27.000000  1.800000   87.000000             no   no   3.0  3.0
# 4       Male  22.000000  1.780000   89.800000             no   no   2.0  1.0
# ...      ...        ...       ...         ...            ...  ...   ...  ...
# 2106  Female  20.976842  1.710730  131.408528            yes  yes   3.0  3.0
# 2107  Female  21.982942  1.748584  133.742943            yes  yes   3.0  3.0
# 2108  Female  22.524036  1.752206  133.689352            yes  yes   3.0  3.0
# 2109  Female  24.361936  1.739450  133.346641            yes  yes   3.0  3.0
# 2110  Female  23.664709  1.738836  133.472641            yes  yes   3.0  3.0
#
# ...

# %%
# Display the first few rows of the DataFrame
newData.head()
# Out:
#    Gender   Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female  21.0    1.62    64.0            yes   no   2.0  3.0  Sometimes
# 1  Female  21.0    1.52    56.0            yes   no   3.0  3.0  Sometimes
# 2    Male  23.0    1.80    77.0            yes   no   2.0  3.0  Sometimes
# 3    Male  27.0    1.80    87.0             no   no   3.0  3.0  Sometimes
# 4    Male  22.0    1.78    89.8             no   no   2.0  1.0  Sometimes
#
#   SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3    no   2.0   no  2.0  0.0  Frequently                Walking
# 4    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity
# 0        Normal_Weight
# 1        Normal_Weight
# 2        Normal_Weight
# 3   Overweight_Level_I
# ...

# %%
# Display the last few rows of the DataFrame
newData.tail()
# Out:
#       Gender        Age    Height      Weight family_history FAVC  FCVC  NCP  \
# 2106  Female  20.976842  1.710730  131.408528            yes  yes   3.0  3.0
# 2107  Female  21.982942  1.748584  133.742943            yes  yes   3.0  3.0
# 2108  Female  22.524036  1.752206  133.689352            yes  yes   3.0  3.0
# 2109  Female  24.361936  1.739450  133.346641            yes  yes   3.0  3.0
# 2110  Female  23.664709  1.738836  133.472641            yes  yes   3.0  3.0
#
#            CAEC SMOKE      CH2O SCC       FAF       TUE       CALC  \
# 2106  Sometimes    no  1.728139  no  1.676269  0.906247  Sometimes
# 2107  Sometimes    no  2.005130  no  1.341390  0.599270  Sometimes
# 2108  Sometimes    no  2.054193  no  1.414209  0.646288  Sometimes
# 2109  Sometimes    no  2.852339  no  1.139107  0.586035  Sometimes
# 2110  Sometimes    no  2.863513  no  1.026452  0.714137  Sometimes
#
#                      MTRANS           Obesity
# 2106  Public_Transportation  Obesity_Type_III
# ...

# %%
# Display random sample of 2 rows from the DataFrame
newData.sample(2)
# Out:
#       Gender        Age    Height      Weight family_history FAVC  FCVC  NCP  \
# 1935  Female  21.412434  1.675562  121.639178            yes  yes   3.0  3.0
# 145     Male  21.000000  1.620000   70.000000             no  yes   2.0  1.0
#
#            CAEC SMOKE      CH2O SCC      FAF       TUE       CALC  \
# 1935  Sometimes    no  1.484938  no  0.74225  0.604692  Sometimes
# 145          no    no  3.000000  no  1.00000  0.000000  Sometimes
#
#                      MTRANS             Obesity
# 1935  Public_Transportation    Obesity_Type_III
# 145   Public_Transportation  Overweight_Level_I

# %%
# Display random sample of 4 rows from the DataFrame with a fixed random state for reproducibility
# random_state ensures that the same rows are returned each time the code is run
newData.sample(4, random_state=1)
# Out:
#       Gender       Age    Height      Weight family_history FAVC      FCVC  \
# 553     Male  16.30687  1.752755   50.000000             no  yes  2.310423
# 331     Male  17.00000  1.740000   56.000000            yes  yes  2.000000
# 241     Male  22.00000  1.600000   66.000000             no  yes  3.000000
# 1957  Female  26.00000  1.641209  111.856492            yes  yes  3.000000
#
#            NCP       CAEC SMOKE      CH2O SCC       FAF       TUE       CALC  \
# 553   3.558637  Sometimes    no  1.787843  no  1.926592  0.828549  Sometimes
# 331   3.000000  Sometimes    no  2.000000  no  2.000000  1.000000         no
# 241   3.000000  Sometimes    no  2.000000  no  3.000000  0.000000         no
# 1957  3.000000  Sometimes    no  2.621877  no  0.000000  0.153669  Sometimes
#
#                      MTRANS              Obesity
# 553   Public_Transportation  Insufficient_Weight
# 331   Public_Transportation        Normal_Weight
# 241                    Bike   Overweight_Level_I
# ...

# %%
# Display the column names of the DataFrame
newData.columns
# Out:
# Index(['Gender', 'Age', 'Height', 'Weight', 'family_history', 'FAVC', 'FCVC',
#        'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE', 'CALC', 'MTRANS',
#        'Obesity'],
#       dtype='object')

# %%
# Display the shape of the DataFrame (number of rows and columns)
newData.shape
# Out:
# (2111, 17)

# %%
# Display information about the DataFrame including data types and non-null counts
newData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          2111 non-null   object
#  1   Age             2111 non-null   float64
#  2   Height          2111 non-null   float64
#  3   Weight          2111 non-null   float64
#  4   family_history  2111 non-null   object
#  5   FAVC            2111 non-null   object
#  6   FCVC            2111 non-null   float64
#  7   NCP             2111 non-null   float64
#  8   CAEC            2111 non-null   object
#  9   SMOKE           2111 non-null   object
#  10  CH2O            2111 non-null   float64
#  11  SCC             2111 non-null   object
#  12  FAF             2111 non-null   float64
#  13  TUE             2111 non-null   float64
#  14  CALC            2111 non-null   object
#  15  MTRANS          2111 non-null   object
#  16  Obesity         2111 non-null   object
# ...

# %%
# Display summary statistics of the DataFrame including count, mean, std, min, max, and quartiles
newData.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     24.312600     1.701677    86.586058     2.419043     2.685628
# std       6.345968     0.093305    26.191172     0.533927     0.778039
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      19.947192     1.630000    65.473343     2.000000     2.658738
# 50%      22.777890     1.700499    83.000000     2.385502     3.000000
# 75%      26.000000     1.768464   107.430682     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2111.000000  2111.000000  2111.000000
# mean      2.008011     1.010298     0.657866
# std       0.612953     0.850592     0.608927
# min       1.000000     0.000000     0.000000
# 25%       1.584812     0.124505     0.000000
# 50%       2.000000     1.000000     0.625350
# ...

# %%
# Location based indexing with .loc
# Display the values of the 'Age', 'Height', and 'Weight' columns at first row (index 0)
# Use .loc to access the row and column .loc[row_index, column_label]
newData.loc[0, ['Age', 'Height', 'Weight']]
# Out:
# Age       21.0
# Height    1.62
# Weight    64.0
# Name: 0, dtype: object

# %%
# Display the values of the 'Age', 'Height', and 'Weight' columns for the first 10 rows
# In slicing last row & column is also inculded
newData.loc[0:10, 'Age':'FAF']
# Out:
#      Age  Height  Weight family_history FAVC  FCVC  NCP        CAEC SMOKE  \
# 0   21.0    1.62    64.0            yes   no   2.0  3.0   Sometimes    no
# 1   21.0    1.52    56.0            yes   no   3.0  3.0   Sometimes   yes
# 2   23.0    1.80    77.0            yes   no   2.0  3.0   Sometimes    no
# 3   27.0    1.80    87.0             no   no   3.0  3.0   Sometimes    no
# 4   22.0    1.78    89.8             no   no   2.0  1.0   Sometimes    no
# 5   29.0    1.62    53.0             no  yes   2.0  3.0   Sometimes    no
# 6   23.0    1.50    55.0            yes  yes   3.0  3.0   Sometimes    no
# 7   22.0    1.64    53.0             no   no   2.0  3.0   Sometimes    no
# 8   24.0    1.78    64.0            yes  yes   3.0  3.0   Sometimes    no
# 9   22.0    1.72    68.0            yes  yes   2.0  3.0   Sometimes    no
# 10  26.0    1.85   105.0            yes  yes   3.0  3.0  Frequently    no
#
#     CH2O  SCC  FAF
# 0    2.0   no  0.0
# 1    3.0  yes  3.0
# ...

# %%
# Display all rows
newData.loc[:, 'Age':'Weight']
# Out:
#             Age    Height      Weight
# 0     21.000000  1.620000   64.000000
# 1     21.000000  1.520000   56.000000
# 2     23.000000  1.800000   77.000000
# 3     27.000000  1.800000   87.000000
# 4     22.000000  1.780000   89.800000
# ...         ...       ...         ...
# 2106  20.976842  1.710730  131.408528
# 2107  21.982942  1.748584  133.742943
# 2108  22.524036  1.752206  133.689352
# 2109  24.361936  1.739450  133.346641
# 2110  23.664709  1.738836  133.472641
#
# [2111 rows x 3 columns]

# %%
# Integer based indexing with .iloc
# Display the values of the first three columns at the first row (index 0), Column must be integer
newData.iloc[0, 0]
# Out:
# 'Female'

# %%
# Slicing with .iloc to get first 3 rows and first 3 columns
# In slicing last row & column is excluded (Only with .iloc)
newData.iloc[0:3, 0:3]
# Out:
#    Gender   Age  Height
# 0  Female  21.0    1.62
# 1  Female  21.0    1.52
# 2    Male  23.0    1.80

# %%
# Accessing single value using .at (Slicing is not allowed with .at)
# Display the value of the 'Age' column at the first row (index 0)
newData.at[0, 'Age']
# Out:
# np.float64(21.0)

# %%
# Accessing single value using .iat (Slicing is not allowed with .iat)
# Display the value at the first row (index 0) and first column (index 0), Column must be integer
newData.iat[0, 0]
# Out:
# 'Female'

# %%
# Display the 'Age' column for all rows
newData['Age']
# Out:
# 0       21.000000
# 1       21.000000
# 2       23.000000
# 3       27.000000
# 4       22.000000
#           ...
# 2106    20.976842
# 2107    21.982942
# 2108    22.524036
# 2109    24.361936
# 2110    23.664709
# Name: Age, Length: 2111, dtype: float64

# %%
# Display the 'Age', 'Height', and 'Weight' columns for all rows
newData[['Age', 'Height', 'Weight']]
# Out:
#             Age    Height      Weight
# 0     21.000000  1.620000   64.000000
# 1     21.000000  1.520000   56.000000
# 2     23.000000  1.800000   77.000000
# 3     27.000000  1.800000   87.000000
# 4     22.000000  1.780000   89.800000
# ...         ...       ...         ...
# 2106  20.976842  1.710730  131.408528
# 2107  21.982942  1.748584  133.742943
# 2108  22.524036  1.752206  133.689352
# 2109  24.361936  1.739450  133.346641
# 2110  23.664709  1.738836  133.472641
#
# [2111 rows x 3 columns]
